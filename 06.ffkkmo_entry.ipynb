# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import re
import urllib.parse
from tqdm.notebook import tqdm

# %%
def parse_entry_line(line):
    cells = line.find_all('td')
    if len(cells) < 4:
        return False
    full_name = cells[1].a.text
    club = cells[2].text
    full_name = full_name.replace("ё", "е").replace("Ё", "Е")
    club = club.replace("ё", "е").replace("Ё", "Е")
    full_name = [x.strip() for x in full_name.split()]
    if len(full_name) == 2:
        first_name = full_name[0]
        middle_name = ""
        last_name = full_name[1]
    elif len(full_name) == 3:
        first_name = full_name[0]
        middle_name = full_name[1]
        last_name = full_name[2]
    else:
        return False
    return {
        'firstname': first_name,
        'middlename': middle_name,
        'lastname': last_name,
        'club': club,
    }

# %%
def parse_event(event_link, data, judges):
    soup = BeautifulSoup(requests.get(event_link).text, 'html.parser')
    title = soup.find("h1", "entry-title").text
    date = soup.find("div", "competition-date").p.text.split('-')[0].strip()
    place = soup.find("div", "competition-place").p.span.text.strip()
    online = soup.find("div", "competition-file")
    if online is not None:
        online_link = online.a.get('href')
        online_link = online_link if online_link[-1] == '/' else online_link + '/'
        soup = BeautifulSoup(requests.get(online_link).text, 'html.parser')
        lines = soup.find_all('tr')

        for line in lines:
            columns = line.find_all('td')
            if (len(columns) < 5):
                continue
            if (columns[0].text != ""):
                category = columns[0].text                
                soup = BeautifulSoup(requests.get(urllib.parse.urljoin(online_link, columns[2].a.get("href"))).text, 'html.parser')
                entries = soup.find_all('tr')
                persons = []
                for entry in entries:
                    pdata = parse_entry_line(entry) 
                    if pdata:
                        persons.append(pdata)
            if (columns[1].text != ""):
                segment = columns[1].text
                for person in persons:
                    data['date'].append(date)
                    data['place'].append(place)
                    data['category'].append(category)
                    data['segment'].append(segment)
                    data['firstname'].append(person['firstname'])
                    data['middlename'].append(person['middlename'])
                    data['lastname'].append(person['lastname'])
                    data['club'].append(person['club'])

# %%
data = {
    'date': [],
    'place': [], 
    'category': [],
    'segment': [],
    'firstname': [],
    'middlename': [],
    'lastname': [],
    'club': [],
}
judges = {
    'date': [],
    'place': [], 
    'function': [],
    'name': [],
}
parse_event("http://ffkkmo.ru/competition/%d1%81%d0%bf%d0%be%d1%80%d1%82%d0%b8%d0%b2%d0%bd%d1%8b%d0%b5-%d1%81%d0%be%d1%80%d0%b5%d0%b2%d0%bd%d0%be%d0%b2%d0%b0%d0%bd%d0%b8%d1%8f-%d0%bc%d0%be%d1%81%d0%ba%d0%be%d0%b2%d1%81%d0%ba%d0%be%d0%b9-121/",
           data, judges)

# %%
pd.DataFrame.from_dict(data)
# Out:
#           date                                              place  \
# 0   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 1   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 2   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 3   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 4   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 5   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 6   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 7   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 8   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 9   02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 10  02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 11  02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 12  02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 13  02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 14  02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 15  02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 16  02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
# 17  02.10.2025  г. Ногинск, ул. Климова, д. 48, корпус А, ФОК ...
#
# 32  3-й cпoртивный разряд, дeвушки  Произвольная программа     Варвара
# 33  3-й cпoртивный разряд, дeвушки  Произвольная программа   Мирослава
# 34  2-й cпoртивный разряд, дeвушки      Короткая программа     Валерия
# 35  2-й cпoртивный разряд, дeвушки      Короткая программа   Екатерина
# 36  2-й cпoртивный разряд, дeвушки      Короткая программа     Варвара
# 37  2-й cпoртивный разряд, дeвушки      Короткая программа   Елизавета
# 38  2-й cпoртивный разряд, дeвушки  Произвольная программа     Валерия
# 39  2-й cпoртивный разряд, дeвушки  Произвольная программа   Екатерина
# 40  2-й cпoртивный разряд, дeвушки  Произвольная программа     Варвара
# 41  2-й cпoртивный разряд, дeвушки  Произвольная программа   Елизавета
#
#        middlename     lastname  \
# 0       Ильинична     КЛЕБАНЮК
# 1      Михайловна     АНДРЕЕВА
# 2   Александровна     АНТОНОВА
# 3      Дмитриевна    БАКЛАГИНА
# 4       Антоновна    БОГДАНОВА
# 5    Вячеславовна      ВАСИЛКО
# 6      Дмитриевна       ДОЛОВА
# 7       Сергеевна       КИЗЫМА
# 8   Александровна      НАУМОВА
# 9   Александровна      РУБЦОВА
# 10       Павловна      СМЫГИНА
# 11       Олеговна  ФИЛИПЕНКОВА
# 12      Андреевна    ХРИПЧЕНКО
# 13   Вячеславовна   ВЫТРИШКОВА
# 14      Андреевна    КЛИМАКОВА
# 15      Акмаловна    КУЧКАРОВА
# 16      Сергеевна      ПОЛЕЩУК
# 17       Павловна     СМИРНОВА
# 18    Григорьевна    ТЕРДУНОВА
# 19  Александровна    ВАСИЛЬЕВА
# 20     Дмитриевна     ГЛЯНЕНКО
# 21      Андреевна      ДУШКИНА
# 22      Андреевна     ЕЛИСЕЕВА
# 23     Михайловна      ЗАЙЦЕВА
# 24   Владимировна    КОВШУТИНА
# 25       Павловна    СУНДУКОВА
# 26       Игоревна      ЧАРКИНА
# 27     Дмитриевич    КАПИТОНОВ
# 28      Вадимовна     БАЛЯКИНА
# 29     Евгеньевна      БОЧКОВА
# 30       Ивановна     ГРИШАЕВА
# 31       Олеговна     КИСЕЛЕВА
# 32  Станиславовна   НАЗАРИКОВА
# 33       Петровна     ЦВЯТКОВА
# 34   Владимировна    ЗЕЛЕНКОВА
# 35     Николаевна     КВАРДИНА
# 36      Денисовна     ФЕДОРОВА
# 37     Алексеевна   ЧЕРЕПАНОВА
# 38   Владимировна    ЗЕЛЕНКОВА
# 39     Николаевна     КВАРДИНА
# 40      Денисовна     ФЕДОРОВА
# 41     Алексеевна   ЧЕРЕПАНОВА
#
#                                                  club
# 0                       г. Ногинск, МБУ ДО БГО "СШОР"
# 1                       г. Ногинск, МБУ ДО БГО "СШОР"
