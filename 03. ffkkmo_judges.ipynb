# %%
import requests 
import pandas as pd
import re
import urllib.parse
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Получим датасет

# %%
df = pd.concat(map(lambda x : pd.read_csv(f"ffkkmo_judges_{x}_dump.csv"), ['2021', '2122', '2223', '2324', '2425'])).reset_index(drop=True)
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24959 entries, 0 to 24958
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      24959 non-null  object
#  1   place     24959 non-null  object
#  2   online    24959 non-null  object
#  3   function  24959 non-null  object
#  4   name      24864 non-null  object
# dtypes: object(5)
# memory usage: 975.1+ KB
#          date                                              place  \
# 0  27.09.2020  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
# 1  27.09.2020  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
# 2  27.09.2020  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
# 3  27.09.2020  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
# 4  27.09.2020  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
#
#                                         online              function  \
# 0  http://ffkkmo.ru/events/2021/lytkarino0927/               Referee
# 1  http://ffkkmo.ru/events/2021/lytkarino0927/  Technical Controller
# 2  http://ffkkmo.ru/events/2021/lytkarino0927/  Technical Specialist
# 3  http://ffkkmo.ru/events/2021/lytkarino0927/            Judge No.1
# 4  http://ffkkmo.ru/events/2021/lytkarino0927/            Judge No.2
#
#               name
# 0  Павел ТАТАРЕНКО
# 1     Ольга КОВАЛЬ
# 2   Михаил КАЗАКОВ
# 3  Павел ТАТАРЕНКО
# 4    Юлия СОЛОМИНА

# %%
# Удалим строки без судей
df = df.dropna(subset=['function', 'name'])

# %%
# Приведем типы данных
df['date'] = df['date'].str.strip()
df['date'] = pd.to_datetime(df['date'], format='%d.%m.%Y')

# %%
# Добавим год
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['season'] = df['date'].apply(lambda x: f"{x.year-2001}{x.year-2000}" if x.month < 8 else f"{x.year-2000}{x.year-1999}")

# %%
def replace_duplicates(df, keyword, name, field='function'):
    uniquenames = [ s for s in df[field].unique() if keyword.findall(str(s).lower()) ]
    return df[field].replace(uniquenames, name)

# %%
def get_regex(str_val):
    return re.compile((r"(" + str_val + ")").lower())

# %%
df.name = df.name.str.strip()
df.name = df.name.str.replace("ё", "е")
df.name = df.name.str.replace("Ё", "Е")
df.name = df.name.str.replace("  ", " ")

# %%
[ s for s in df.name.unique() if get_regex('ей РОГ').findall(str(s).lower()) ]
# Out:
# ['Алексей РОГОЗИНСКИЙ',
#  'Mr. Алексей РОГОЗИНСКИЙ',
#  'Аллексей РОГОЗИНСКИЙ',
#  'Алескей РОГОЗИНСКИЙ',
#  'Алексей РОГОЗОНСКИЙ']

# %%
df.drop(df[[True if len(x) <= 1 else False for x in df.name.str.split()]].index, inplace=True)

# %%
df.name = [' '.join([x[1], x[2].upper()]) if len(x) > 2 else ' '.join([x[0], x[1].upper()]) for x in df.name.str.split()]

# %%
df.function = replace_duplicates(df, get_regex('специалист'), 'Технический специалист')
df.function = replace_duplicates(df, get_regex('Specialist'), 'Технический специалист')
df.function = replace_duplicates(df, get_regex('контролер'), 'Технический контролер')
df.function = replace_duplicates(df, get_regex('Controller'), 'Технический контролер')
df.function = replace_duplicates(df, get_regex('Replay'), 'Оператор видеоповтора')
df.function = replace_duplicates(df, get_regex('Data'), 'Оператор ввода данных')
df.function = replace_duplicates(df, get_regex('Referee'), 'Рефери')
df.function = replace_duplicates(df, get_regex('1'), 'Судья')
df.function = replace_duplicates(df, get_regex('2'), 'Судья')
df.function = replace_duplicates(df, get_regex('3'), 'Судья')
df.function = replace_duplicates(df, get_regex('4'), 'Судья')
df.function = replace_duplicates(df, get_regex('5'), 'Судья')
df.function = replace_duplicates(df, get_regex('6'), 'Судья')
df.function = replace_duplicates(df, get_regex('7'), 'Судья')
df.name = replace_duplicates(df, get_regex('шуркалова'), 'Елизавета ВЛАСЕНКО', field='name')
df.name = replace_duplicates(df, get_regex('ей РОГ'), 'Алексей РОГОЗИНСКИЙ', field='name')
df.function.unique()
# Out:
# array(['Рефери', 'Технический контролер', 'Технический специалист',
#        'Судья', 'Оператор видеоповтора', 'Оператор ввода данных'],
#       dtype=object)

# %%
len(df[df['function'] == 'Рефери'])
# Out:
# 3214

# %%
len(df[df['function'] == 'Судья'])
# Out:
# 13193

# %%
len(df)
# Out:
# 24844

# %%
df.reset_index(inplace=True, drop=True)
df.to_csv("ffkkmo_judges_clean.csv")
df
# Out:
#             date                                              place  \
# 0     2020-09-27  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
# 1     2020-09-27  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
# 2     2020-09-27  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
# 3     2020-09-27  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
# 4     2020-09-27  г. Лыткарино, ул. Советская д.9а, ЛСК «Лыткарино»
# ...          ...                                                ...
# 24839 2025-06-14  г. Долгопрудный, пр-кт Ракетостроителей, д. 4,...
# 24840 2025-06-14  г. Долгопрудный, пр-кт Ракетостроителей, д. 4,...
# 24841 2025-06-14  г. Долгопрудный, пр-кт Ракетостроителей, д. 4,...
# 24842 2025-06-14  г. Долгопрудный, пр-кт Ракетостроителей, д. 4,...
# 24843 2025-06-14  г. Долгопрудный, пр-кт Ракетостроителей, д. 4,...
#
#                                             online                function  \
# 0      http://ffkkmo.ru/events/2021/lytkarino0927/                  Рефери
# 1      http://ffkkmo.ru/events/2021/lytkarino0927/   Технический контролер
# 2      http://ffkkmo.ru/events/2021/lytkarino0927/  Технический специалист
# 3      http://ffkkmo.ru/events/2021/lytkarino0927/                   Судья
# 4      http://ffkkmo.ru/events/2021/lytkarino0927/                   Судья
# ...                                            ...                     ...
# 24839         http://ffkkmo.ru/events/2425/dp1406/  Технический специалист
# 24840         http://ffkkmo.ru/events/2425/dp1406/                   Судья
# 24841         http://ffkkmo.ru/events/2425/dp1406/                   Судья
# 24842         http://ffkkmo.ru/events/2425/dp1406/                   Судья
# 24843         http://ffkkmo.ru/events/2425/dp1406/   Оператор ввода данных
#
#                       name  year  month season
# 0          Павел ТАТАРЕНКО  2020      9   2021
# 1             Ольга КОВАЛЬ  2020      9   2021
# 2           Михаил КАЗАКОВ  2020      9   2021
# 3          Павел ТАТАРЕНКО  2020      9   2021
# 4            Юлия СОЛОМИНА  2020      9   2021
# ...                    ...   ...    ...    ...
# 24839    Евгений ПРОКОФЬЕВ  2025      6   2425
# 24840    Светлана СОЛОМИНА  2025      6   2425
# 24841        Даниил СТАРОВ  2025      6   2425
# 24842       Елена БОЛДЕНКО  2025      6   2425
# 24843  Алексей РОГОЗИНСКИЙ  2025      6   2425
#
# [24844 rows x 8 columns]

# %%
pd.pivot_table(df.drop_duplicates(['date', 'name', 'function']), values='date', index='name', columns='function', aggfunc='count')
# Out:
# function                Оператор ввода данных  Оператор видеоповтора  Рефери  \
# name
# Александр КОНДАКОВ                        NaN                    NaN     NaN
# Александр КУЗНЕЦОВ                        NaN                    NaN     NaN
# Александр ПОЛЯКОВ                         NaN                    NaN     NaN
# Александр САМОХВАЛОВ                      NaN                    NaN     NaN
# Александра АВСТРИЙСКАЯ                    NaN                    NaN     NaN
# ...                                       ...                    ...     ...
# Яна СУСЛЕНКО                              NaN                    NaN     3.0
# с С                                       NaN                    NaN     NaN
# судья №1                                  NaN                    NaN     NaN
# судья №2                                  NaN                    NaN     NaN
# судья №3                                  NaN                    NaN     NaN
#
# function                Судья  Технический контролер  Технический специалист
# name
# Александр КОНДАКОВ        NaN                    NaN                    13.0
# Александр КУЗНЕЦОВ        NaN                    NaN                     1.0
# Александр ПОЛЯКОВ        11.0                    NaN                     NaN
# Александр САМОХВАЛОВ      NaN                    NaN                    25.0
# Александра АВСТРИЙСКАЯ    NaN                    NaN                     1.0
# ...                       ...                    ...                     ...
# Яна СУСЛЕНКО              5.0                    1.0                     NaN
# с С                       1.0                    NaN                     NaN
# судья №1                  1.0                    NaN                     NaN
# судья №2                  1.0                    NaN                     NaN
# судья №3                  1.0                    NaN                     NaN
#
# [125 rows x 6 columns]

# %%
temp_df = df[df.season == '2425'].drop_duplicates(['date', 'name', 'function']).groupby(['function', 'name']).count()['date']

# %%
temp_df.loc['Технический специалист'].sort_values(ascending=False)
# Out:
# name
# Станислав КОВАЛЕВ       11
# Евгений ПРОКОФЬЕВ        8
# Александр САМОХВАЛОВ     7
# Александр КОНДАКОВ       6
# Михаил КАЗАКОВ           6
# Елизавета РАЧЕВА         5
# Андрей ЛЕБЕДЬ            3
# Георгий КОЗАЧИНСКИЙ      2
# Мария СЕМЕНОВА           2
# Оксана АНДРИЕНКО         2
# Алксандр КОНДАКОВ        1
# Анастасия ИЛЬЯНОВА       1
# Владислав МИРЗОЕВ        1
# Наталия ЛЕБЕДЕВА         1
# Name: date, dtype: int64

# %%
temp_df.loc['Технический контролер'].sort_values(ascending=False)
# Out:
# name
# Дарья ФИЛЯКИНА           15
# Ольга КОВАЛЬ             10
# Полина МАЗОРЧУК           8
# Елена МЕЛИКОВА            5
# Елизавета КИРИЛЛОВА       3
# Алексей УСАНОВ            2
# Юлия ПТИЦЫНА              2
# Алла ШЕХОВЦОВА            1
# Анастасия ШЕРЕМЕТЬЕВА     1
# Антон ШАРОВ               1
# Елена НОВИКОВА            1
# ПОЛЯКОВА (ПОНОМАРЕВА)     1
# ПТИЦЫНА (СОЛОМИНА)        1
# Полина ГЛУШАК             1
# Полина МОЗАРЧУК           1
# Яна СУСЛЕНКО              1
# Name: date, dtype: int64

# %%
temp_df.loc['Оператор ввода данных'].sort_values(ascending=False)
# Out:
# name
# Алексей РОГОЗИНСКИЙ    31
# Алексей ПОЛЕТОВ         2
# Владислав ГРИЦАЙ        2
# Евгений ПРОКОФЬЕВ       2
# Евгения СУББОТИНА       1
# Михаил КАЗАКОВ          1
# Name: date, dtype: int64

# %%
temp_df.loc['Рефери'].sort_values(ascending=False)
# Out:
# name
# Елена КАЛИНКИНА          17
# Светлана СОЛОМИНА        10
# Евгения СУББОТИНА         5
# Елена МЕЛИКОВА            5
# Дарья ФИЛЯКИНА            4
# Юлия СОЛОМИНА             4
# Дарья НУЖДИНА             2
# Анастасия АГИБАЛОВА       1
# Анастасия ШЕРЕМЕТЬЕВА     1
# Елизавета ВЛАСЕНКО        1
# Елизавета КИРИЛЛОВА       1
# Ольга КОВАЛЬ              1
# Сергей ЧЕМОДАНОВ          1
# Татьяна ФЕДОРОВА          1
# Яна СУСЛЕНКО              1
# Name: date, dtype: int64

# %%
temp_df.loc['Судья'].sort_values(ascending=False).head(20)
# Out:
# name
# Елена КАЛИНКИНА          21
# Елена БОЛДЕНКО           18
# Светлана СОЛОМИНА        15
# Валентина ВОЛКОВА        13
# Александра АСТАФЬЕВА     12
# Анастасия ГОРЯЧЕВА       10
# Татьяна КАМАНИНА         10
# Дарья ФИЛЯКИНА            9
# Людмила ПРОКОФЬЕВА        8
# Екатерина РОМАДАНОВА      7
# Евгения СУББОТИНА         7
# Екатерина ЮДКИНА          6
# Юлия СОЛОМИНА             6
# Елена МЕЛИКОВА            6
# Полина МАЗОРЧУК           5
# Дарья НУЖДИНА             5
# Александра СУДАРИКОВА     5
# Вера НАДЕЕВА              4
# Елена НОВИКОВА            3
# Елизавета КИРИЛЛОВА       3
# Name: date, dtype: int64

# %%
temp_df.index = temp_df.index.swaplevel(0, 1)

# %%
def judge_in_seasons(df, name):
    data = df[df.name == name].groupby(['season']).count()['title']
    ax = data.plot(
        kind='bar', figsize=(20, 5), grid=True
    )
    major_ticks = np.arange(0, max(data) + 1, 1)
    ax.set_yticks(major_ticks)
    plt.title(name, fontsize=32)
    plt.xlabel('Сезон', fontsize=16)
    plt.ylabel(f'Количество участий', fontsize=18)
    plt.xticks(fontsize=20, rotation=50, horizontalalignment='right');

# %%
def judges_in_season(df, season=None, limit=100, plot=True, sort_col='date'):
    if season is None:
        data = df
    else:
        data = df[df['season'] == season]
    data = data.groupby(['name']).count().sort_values(
        by=sort_col, ascending=False).head(limit)['date']
    if plot:
        ax = data.plot(
            kind='bar', figsize=(20, 5), grid=True
        )
        major_ticks = np.arange(0, max(data) + 1, 1)
        if season is not None:
            ax.set_yticks(major_ticks)
            plt.title("Сезон " + season, fontsize=32)
        plt.xlabel('Судья', fontsize=16)
        plt.ylabel(f'Количество участий', fontsize=18)
        plt.xticks(fontsize=20, rotation=50, horizontalalignment='right');
    else:
        return data

# %%
judges_in_season(df.drop_duplicates(['date', 'name']), limit=35)

# %%
judge_in_seasons(df.drop_duplicates(['date', 'name']), 'Павел ТАТАРЕНКО')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 judge_in_seasons(df.drop_duplicates(['date', 'name']), 'Павел ТАТАРЕНКО')
#
# Cell In[54], line 2, in judge_in_seasons(df, name)
#       1 def judge_in_seasons(df, name):
# ----> 2     data = df[df.name == name].groupby(['season']).count()['title']
#       3     ax = data.plot(
#       4         kind='bar', figsize=(20, 5), grid=True
#       5     )
#       6     major_ticks = np.arange(0, max(data) + 1, 1)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'title'

# %%
df[df.name == 'Елизавета ВЛАСЕНКО']
