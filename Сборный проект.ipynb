# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Евгений :)  Спасибо за работу, все исправления и комментарии
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез, интерпретации значения p-value
#  + формировании рекомендаций для бизнеса
#
# <b>Навыки первого модуля освоены хорошо</b>
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# добавил пару новых подсказок

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Да, Ринат, видно случайно отправил старый вариант, прошу прощения, виноват 😞 Спасибо, в очередной раз за ревью! Твое ревье отличается от предыдущих, все по делу, жаль только не так много времени я на это заложил. Удалось более подробно влиться в тему, спасибо за дополнительные материалы, еще не все изучил, но обязательно все посмотрю! И спасибо за бонусы и дополнительные фишки типа, display(), точки с запятой на последней строчке, сложение столбцов в одной строчке. 🙏🙏🙏 Надеюсь, если меня не отчислят, следующие мои проекты будешь проверять ты )))

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Спасибо за добрые слова, выбор ревьюера происходит рандомно 🤝

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Спасибо, Ринат за качественное ревью! Надеюсь все удалось исправить, а то у меня сегодня последний срок сдачи проекта, а дальше отчисление, академов больше не осталось 😞

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Привет, Евгений :) Спасибо за работу, все исправления, комментарии и добрые слова
#
# Стоит планировать на сдачу проекта ревьюеру около 3-х суток, т.к. могут быть разные вопросы
#
# __Стоит завершить исправление комментариев__
#
#
#  + заполнение пропусков, ссылку дублирую
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#  + создать актуальную выборку
#  + поправить исследование зависимости по платформам конкурентам (от оценок критиков и пользователей)
#  + в разделе проверки гипотез подправить выборки
#
# два последних комментария зависят от исправления первого
#
#
# оставил комментарий про расшифровку р-значения, новые подсказки и добавил бонус
#
# Кажется куратор может пойти на встречу и дать нам еще 12-14 часов на завершение проекта, можешь сослаться на меня и сказать, что ревьюер просил об отстрочке 🤝

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Евгений :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# # Сборный проект. Интернет-магазин «Стримчик»

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# ## Инструкция по выполнению проекта
# ### Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/games.csv. Скачать датасет
# ### Шаг 2. Подготовьте данные
# Замените названия столбцов (приведите к нижнему регистру);
# - Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# - Обработайте пропуски при необходимости:
# - Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# - Опишите причины, которые могли привести к пропускам;
# - Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
# - Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# ### Шаг 3. Проведите исследовательский анализ данных
# - Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# - Не учитывайте в работе данные за предыдущие годы.
# - Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# - Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# - Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# - Соотнесите выводы с продажами игр на других платформах.
# - Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# ### Шаг 4. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# ### Шаг 5. Проверьте гипотезы
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# - Как вы сформулировали нулевую и альтернативную гипотезы;
# - Какой критерий применили для проверки гипотез и почему.
#
# ### Шаг 6. Напишите общий вывод
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название придаст вес проекту
#
# а подробности выполнения проекта дадут возможность вспомнить через полгода — что мы тут делали

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %% [markdown]
# ### Описание
#
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Нужно отработать принцип работы с данными.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %% [markdown]
# ## Шаг 1 Откроем файл с данными и изучим общую информацию

# %%
games_df = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')
current_year = 2016

# %%
def primary_information(dataset):
    display(games_df.info())
    display(games_df.head())

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ <b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br /> display() вместо print(), поможет навести красоту на проекте
#
#     print(games_df.head())

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все  методы можно собрать в функцию и оптимизировать код вывода первичной информации
#
#         dataset.head()
#         dataset.info()

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил

# %%
primary_information(games_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# None
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# ...

# %% [markdown]
# Посмотрим наличие пропусков в данных

# %%
games_df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')
        );
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(games_df)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# __мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?__

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Думаю не хватает подписей и сетки

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается, к вопросу сетки вернемся на втором модуле
#
# Цвет у шрифта заголовка почти совпадает с цветом у баров
#
# За поворот текста на оси `У` отвечает параметр rot, можно добавить обозначение оси `Х` (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках
#
# добавить подписи к осям мешает строка кода
#
#         .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')
#
# её можно заменить на
#
#         plt.title('Пропущенные значения, %' + "\n", fontsize=22, color='SteelBlue')
#         plt.xlabel('Процент пропусков', fontsize=22)
#         plt.ylabel('Столбцы с пропусками')
#
# плюс можно установить шкалу от 0 до 100
#
#         plt.xlim(0, 100)
#
# часть новых шрифтов оформлена не совсем корректно 🤝😉

# %% [markdown]
# ## Шаг 2 Подготовим данные

# %% [markdown]
# Приведем названия столбцов к нижнему регистру

# %%
games_df.columns = games_df.columns.str.lower()

# %% [markdown]
# Имеем пропуски в столбцах:
# - year_of_release (269)
# - genre (2)
# - critic_score (8578)
# - user_score (6701)
# - rating (6766)
#
# Записями с пропущенными значениями в полях year_of_release и genre из-за малого их количества можем принебречь и удалить

# %% [markdown]
# Посмотрим, сколько продаж приходится на позиции с пропущенными значениями

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Решение верное, перед удалением стоит посмотреть на записи — может они по 100 млн. продаж принесли ...
#
# На этом проекте мы работаем с продажами, поэтому включается другой фактор, кроме процента потерь ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил проверку ниже

# %%
(
    games_df[
        games_df['year_of_release'].isna() | games_df['genre'].isna()]
        [['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)
)
# Out:
# 183      5.24
# 377      3.50
# 456      3.06
# 475      3.00
# 609      2.53
#          ...
# 16373    0.01
# 16405    0.01
# 16448    0.01
# 16458    0.01
# 16522    0.01
# Length: 271, dtype: float64

# %%
games_df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1).plot.box();

# %%
games_df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1).plot.box(ylim=(0, 6));

# %% [markdown]
# Количество записей с существенным продажами не велико. Самый большой объем продаж из них составил 5.24 млн проданных копий. Отсутствие этих значений картину не изменят, поэтому можем удалить пропущенные значения

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %%
games_df.drop(games_df[games_df['year_of_release'].isna()].index, inplace = True)
games_df.drop(games_df[games_df['genre'].isna()].index, inplace = True)

# %% [markdown]
# В поле user_score встречается строковое значение "tbd". Эта аббревиатура обозначает, что пока пользовательской оценки нет, она будет определена в будущем. Значит это значение отсутствует, заменим его на NaN чтобы можно было преобразовать столбец к вещественному типу

# %%
games_df.loc[(games_df['user_score'] == 'tbd'), 'user_score'] = None

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %% [markdown]
# Преобразуем типы следующих столбцов:
# - year_of_release приведем к целочисленному типу
# - user_score к вещественному типу

# %%
games_df['user_score'] = games_df['user_score'].astype('float64')
games_df['year_of_release'] = games_df['year_of_release'].astype('int64')

# %% [markdown]
# Проанализируем рейтинг ESRB. ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков». Существуют следующие варианты:
# - «EC» («Early childhood») — «Для детей младшего возраста»
# - «E» («Everyone») — «Для всех»
# - «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»
# - «T» («Teen») — «Подросткам»
# - «M» («Mature») — «Для взрослых»
# - «AO» («Adults Only 18+») — «Только для взрослых»
# - «RP» («Rating Pending») — «Рейтинг ожидается»
# - «RP 17+» («Rating Pending») — «Рейтинг ожидается - примерно 17+»
#
# Посмотрим что имеется в нашей выборке:

# %%
games_df['rating'].value_counts()
# Out:
# E       3921
# T       2905
# M       1536
# E10+    1393
# EC         8
# K-A        3
# AO         1
# RP         1
# Name: rating, dtype: int64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Рейтинг ESRB — категориальные данные, стоит внимательно взглянуть на содержимое и предложить чем заполнить пропуски, возможно это поможет найти необычные различия в поведении клиентов
#
# Т.к. записи с пропусками не учитываются при группировке данных, мы не сможем выявить реальный портрет игрока
#
# допом можно подумать над сокращением количества категорий
#
#         E       3924
#         T       2905
#         M       1536
#         E10+    1393
#
#         EC         8
#         RP         1
#         AO         1

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил ниже

# %% [markdown]
# Рейтинг «E» («Everyone») — «Для всех» первоначально назывался "K-A" ("Kids to Adults") поэтому правильно будет "K-A" объединить с "E"
# Также можно объединить M c AO и E и EC

# %%
games_df.loc[games_df['rating'] == "K-A", 'rating'] = "E"
games_df.loc[games_df['rating'] == "AO", 'rating'] = "M"
games_df.loc[games_df['rating'] == "EC", 'rating'] = "E"
games_df.loc[games_df['rating'] == "RP", 'rating'] = "E"
games_df['rating'].value_counts()
# Out:
# E       3933
# T       2905
# M       1537
# E10+    1393
# Name: rating, dtype: int64

# %% [markdown]
# На категорию очень сильно влияет игровой жанр. Поэтому посмотрим количество категорий в каждом из жанров

# %%
genre_rating = games_df.groupby(by='genre')['rating'].value_counts()
genre_rating
# Out:
# genre         rating
# Action        T          670
#               M          597
#               E10+       468
#               E          411
# Adventure     E          161
#               T          114
#               M           98
#               E10+        67
# Fighting      T          357
#               M           48
#               E10+        19
#               E            8
# Misc          E          455
#               T          228
#               E10+       166
#               M           13
# Platform      E          354
#               E10+       141
#               T           63
#               M            3
# Puzzle        E          284
#               E10+        42
#               T           10
# Racing        E          576
#               T          167
#               E10+        95
#               M           18
# Role-Playing  T          415
#               M          161
#               E10+       111
#               E           83
# ...

# %% [markdown]
# Пропуски категорий заполним самой популярной категорией в кажом жанре:

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Рейтинг ESRB — категориальные данные. Стоит ли применять подобный способ заполнения пропусков. Сможем ли мы корректно учесть особенности выборки
#
#         Рейтинги для жанра Shooter
#         M       553
#         T       340
#         E10+     56
#         E        47
#
# Стоит ли все игры с пропусками для данного жанра переводить в рейтинг для  взрослых?
#
#         553 и 340 имеют примерно одинаковый вес ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> В таком случае, я думаю, что ни один из вариантов заполнения пропусков картину анализа данных в дальнейшем случае не улучшит. Поэтому считаю, что нужно все-таки эти пропуски не заполнять

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты проделал большую работу по восстановлению пропусков. Но иногда пропуск сам по себе является ценной информацией. Для каких стран создавалась система ESRB? Будут ли стараться авторы игр для локального рынка других стран получить рейтинг ESRB?
#
# Оптимальнее на данном проекте использовать категорию «неизвестный рейтинг» ...

# %% [markdown]
# Пропущенные значения в категориальной переменной заменять не будем, а вот с количественными подумаем, что сможем сделать с пропусками в полях:
# - critic_score
# - user_score

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Скажи пожалуйста, какое преимущество ты получаешь от заполнения пропусков в числовых колонках на этом проекте, с этой главной задачей?
#
#         Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я понимаю это так, что если не заполнять пропуски, мы сильно сокращаем выборку для анализа. Поэтому заполняем эти значения такой характеристикой, которая устойчива к выбросам, чтобы не исказить картину

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />На этом проекте, с этой главной задачей нет никаких преимуществ от заполнения маркерами пропусков в числовых колонках. Наоборот - мы увеличиваем себе трудозатраты на фильтрацию маркеров

# %%
games_df[['critic_score', 'user_score']].isna().sum()
# Out:
# critic_score    8461
# user_score      8981
# dtype: int64

# %% [markdown]
# Для этого построим гистограммы:

# %%
games_df[['user_score', 'critic_score']].hist(figsize=(15, 5))
# Out:
# array([[<AxesSubplot:title={'center':'user_score'}>,
#         <AxesSubplot:title={'center':'critic_score'}>]], dtype=object)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#         array([[<AxesSubplot:title={'center':'user_score'}>,
#                 <AxesSubplot:title={'center':'critic_score'}>]], dtype=object)
#
# games_df[['user_score', 'critic_score']].hist(figsize=(15, 5));

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Предполагаю, что данные собирались с разных источников и в каких-то источниках данные user_score и critic_score отсутствовали. Поэтому их можно отнести к категории MCAR и в этом случае игнорирование записей, содержащих пропущенные данные, не ведет к искажению результатов.

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %% [markdown]
# Заполним пропущенные значения медианой, потому что данная характеристика устойчива к выбросам и не исказит нормальное распределение

# %% [markdown]
# Сначала заполним медианой выборки с уникальными парами платформа-год:

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Невозможно корректно заполнить 8000 пропусков в количественных колонках на этом проекте. Стоит отменить заполнение

# %% [markdown]
# Проверим на наличие пропусков:

# %%
pass_value_barh(games_df)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Скажи пожалуйста, стоит ли применять подобный способ заполнения пропусков. Сможем ли мы корректно учесть особенности выборки
#
#         games_df.loc[(games_df['user_score'].isna()), 'user_score'] = games_df['user_score'].median()
#         games_df.loc[(games_df['critic_score'].isna()), 'critic_score'] = games_df['critic_score'].median()
#
# Например разные платформы, разные года выпуска, более 8000 пропусков
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил

# %% [markdown]
# #### Посчитаем суммарные продажи во всех регионах и запишим их в отдельный столбец.

# %%
games_df['total_sales'] = games_df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил 👍 спасибо

# %%
# check
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
#  11  total_sales      16444 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить вывод по результатам выполнения раздела проекта

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Датасет не проверен на наличие простых дубликатов
#
# __Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса__

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого категориальных колонок к нижнему регистру
#
# В сырой выборке имеется 2 строчки неполных дубликатов
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил ниже

# %% [markdown]
# Проверим наличие дубликатов по ключевым столбцам ['name', 'platform', 'year_of_release'] и удалим их:

# %%
games_df[games_df.duplicated(['name', 'platform', 'year_of_release'])]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 16230  Madden NFL 13      PS3             2012  Sports       0.0      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  total_sales
# 16230       0.0          0.0          83.0         5.5      E         0.01

# %%
games_df.drop(games_df[games_df.duplicated(['name', 'platform', 'year_of_release'])].index, inplace = True)

# %% [markdown]
# #### Резюме
# - Приведены к нижнему регистру символ в названиях столбцов
# - Значение в поле user_score "tbd" было заменено на NaN чтобы можно было преобразовать столбец к вещественному типу
# - Тип данных year_of_release был приведен к целочисленному типу
# - Тип данных user_score был приведен к вещественному типу
# - Записи с пропусками в полях year_of_release и genre из-за малого их количества и малой значимости были удалены
# - Малочисленные категории в рейтинге были объединены, а пропуски заполнены самой популярной категорией в каждом жанре
# - Пропуски в полях user_score и critic_score заполнены медианой в соответствии с платформой и годом выпуска
# - Удалены дубликаты по ключевым столбцам 'name', 'platform', 'year_of_release'

# %% [markdown]
# ## Шаг 3. Проведём исследовательский анализ данных

# %% [markdown]
# #### Проанализируем, сколько игр выпускалось в разные годы

# %%
games_df.pivot_table(
    index='year_of_release',
    values='name',
    aggfunc='count'
).plot(
    kind='bar', 
    grid=True, 
    legend = False,
    figsize=(15, 5)
)
plt.title('Распределение количества выпуcкаемых игр по годам')
plt.xlabel('Год')
plt.ylabel('Количество игр')
# Out:
# Text(0, 0.5, 'Количество игр')

# %% [markdown]
# Данные до 1994 года особого интереса не представляют. В этот период игры были еще не популярны и продаж было мало. Пик популярности пришел на 2008-2009 год, в этот период выпускалось более 1400 игр в год.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, все элементы добавлены, молодец
#
#         Стоит скрыть легенду, она не несет никакой полезной информации

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скрыл

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %% [markdown]
# #### Выберем платформы с наибольшими суммарными продажами и построим распределение по годам

# %%
games_df.pivot_table(
    index='year_of_release', 
    columns='platform',
    values='total_sales', 
    fill_value=0,
    aggfunc='sum').head(10)
# Out:
# platform          2600  3DO  3DS   DC    DS     GB  GBA   GC  GEN   GG  ...  \
# year_of_release                                                         ...
# 1980             11.38  0.0  0.0  0.0  0.00   0.00  0.0  0.0  0.0  0.0  ...
# 1981             35.68  0.0  0.0  0.0  0.00   0.00  0.0  0.0  0.0  0.0  ...
# 1982             28.88  0.0  0.0  0.0  0.00   0.00  0.0  0.0  0.0  0.0  ...
# 1983              5.84  0.0  0.0  0.0  0.00   0.00  0.0  0.0  0.0  0.0  ...
# 1984              0.27  0.0  0.0  0.0  0.00   0.00  0.0  0.0  0.0  0.0  ...
# 1985              0.45  0.0  0.0  0.0  0.02   0.00  0.0  0.0  0.0  0.0  ...
# 1986              0.67  0.0  0.0  0.0  0.00   0.00  0.0  0.0  0.0  0.0  ...
# 1987              1.94  0.0  0.0  0.0  0.00   0.00  0.0  0.0  0.0  0.0  ...
# 1988              0.74  0.0  0.0  0.0  0.00   1.43  0.0  0.0  0.0  0.0  ...
# 1989              0.63  0.0  0.0  0.0  0.00  64.97  0.0  0.0  0.0  0.0  ...
#
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделал ниже, платформа массово появляется в 2004 году, удалим запись за 1985 год как аномалию

# %%
games_df[games_df['platform'] == 'DS'].sort_values(by='year_of_release')
# Out:
#                                                  name platform  \
# 15957             Strongest Tokyo University Shogi DS       DS
# 13463                               Cocoto Kart Racer       DS
# 11517                           Kenshuui Tendo Dokuta       DS
# 4421   The Urbz: Sims in the City (all regions sales)       DS
# 7902                          Daigasso! Band Brothers       DS
# ...                                               ...      ...
# 7460                                  Disney's Planes       DS
# 14716          LEGO Legends of Chima: Laval's Journey       DS
# 7993                                     The Smurfs 2       DS
# 3862                             Frozen: Olaf's Quest       DS
# 5054                         LEGO Marvel Super Heroes       DS
#
#        year_of_release       genre  na_sales  eu_sales  jp_sales  other_sales  \
# 15957             1985      Action      0.00      0.00      0.02         0.00
# ...

# %% [markdown]
# Видим, что платформа массово появляется в 2004 году, удалим запись за 1985 год как аномалию

# %%
games_df.drop(games_df[(games_df['year_of_release'] == 1985) & (games_df['platform'] == 'DS')].index, inplace = True)

# %%
popular_platforms = games_df.pivot_table(
    index='year_of_release', 
    columns='platform',
    values='total_sales', 
    fill_value=0,
    aggfunc='sum').sum().sort_values(ascending=False)[:5]

# %% [markdown]
# За всю историю самые продаваемые платформы:

# %%
popular_platforms
# Out:
# platform
# PS2     1233.56
# X360     961.24
# PS3      931.33
# Wii      891.18
# DS       802.76
# dtype: float64

# %%
games_df[games_df['platform'].isin(list(popular_platforms.index))].pivot_table(
    index='year_of_release', 
    columns='platform',
    values='total_sales', 
    fill_value=0,
    aggfunc='sum').plot(
    grid=True,
    figsize=(15, 10)
)
plt.title('Распределение суммарных продаж по годам у популярных платформ')
plt.xlabel('Год')
plt.ylabel('Суммарные продажи');

# %% [markdown]
# На графике видно, что приблизительное время выхода платформы на пик популярности - 5 лет, а через следующие 5 лет платформа теряет актуальность, исходя из этого примем актуальным период 10 лет

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит определить характерный срок от начала до завершения продаж по крупным платформам

# %% [markdown]
# #### Посмотрим какие платформы лидируют по продажам, растут или падают. Выберем 5 самых продаваемых платформ

# %%
games_df[(games_df['year_of_release'] > current_year-10)].pivot_table(
    index='year_of_release',
    columns='platform',
    values='total_sales', 
    fill_value=0,
    aggfunc='sum'
)
# Out:
# platform           3DS    DC      DS  GBA    GC     PC    PS2     PS3     PS4  \
# year_of_release
# 2007              0.00  0.02  146.94  3.4  0.27   9.28  75.99   73.19    0.00
# 2008              0.00  0.04  145.31  0.0  0.00  12.42  53.90  118.52    0.00
# 2009              0.00  0.00  119.54  0.0  0.00  16.91  26.40  130.93    0.00
# 2010              0.00  0.00   85.02  0.0  0.00  24.28   5.64  142.17    0.00
# 2011             63.20  0.00   26.18  0.0  0.00  35.03   0.45  156.78    0.00
# 2012             51.36  0.00   11.01  0.0  0.00  23.22   0.00  107.35    0.00
# 2013             56.57  0.00    1.54  0.0  0.00  12.38   0.00  113.25   25.99
# 2014             43.76  0.00    0.00  0.0  0.00  13.28   0.00   47.76  100.00
# 2015             27.78  0.00    0.00  0.0  0.00   8.52   0.00   16.82  118.90
# 2016             15.14  0.00    0.00  0.0  0.00   5.25   0.00    3.60   69.25
#
# platform           PSP    PSV     Wii   WiiU    X360    XB   XOne
# year_of_release
# ...

# %%
games_df[(games_df['year_of_release'] > current_year-10)].pivot_table(
    index='year_of_release',
    columns='platform',
    values='name', 
    fill_value=0,
    aggfunc='count'
).plot(
    figsize=(15, 10),
    grid=True
)
plt.title('Распределение количества выпуcкаемых игр по годам у популярных платформ')
plt.xlabel('Год')
plt.ylabel('Количество игр')
# Out:
# Text(0, 0.5, 'Количество игр')

# %%
actual_period = 3

# %%
act_df = games_df[(games_df['year_of_release'] > current_year-actual_period)]
act_df
# Out:
#                                             name platform  year_of_release  \
# 31                     Call of Duty: Black Ops 3      PS4             2015
# 42                            Grand Theft Auto V      PS4             2014
# 47     Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 77                                       FIFA 16      PS4             2015
# 87                  Star Wars Battlefront (2015)      PS4             2015
# ...                                          ...      ...              ...
# 16703                           Strawberry Nauts      PSV             2016
# 16707                           Aiyoku no Eustia      PSV             2014
# 16710              Samurai Warriors: Sanada Maru      PS3             2016
# 16712                    Haitaka no Psychedelica      PSV             2016
# 16714                        Winning Post 8 2016      PSV             2016
#
# ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я думаю, что характерный срок от начала до завершения продаж по крупным платформам в среднем 10 лет, но актуальный период который поможет составить прогноз на 2017 год составляет 3 года

# %% [markdown]
# По графикам можно сказать, что в набирают популярность только две платформы, PS4 и XOne, на них можно ориентироваться в 2017 году. Платформы PS3 и X360 теряют свою актуальность и делать упор на них в 2017 году не стоит. Платформа 3DS находится в нейтральном состоянии и списывать её со счетов пока не стоит. Тем более, что в описании проекта указано, что данные за 2016 год могут быть неполными. Также в топ можно добавить WiiU и PSV. Топ-5 получился следующий:
# - PS4
# - XOne
# - 3DS
# - WiiU
# - PSV

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# + Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# + Не учитывайте в работе данные за предыдущие годы.
#
#
# __Стоит создать актуальную выборку и далее все исследования на проекте, кроме разделов__
#
# + Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# + Соотнесите выводы с продажами игр на других платформах.
#
# __выполняем на актуальных данных__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />за 2016 год данные неполные, фактически у нас для анализа взят только один полный год — 2015, на рабочих проектах можем упустить фактор сезонности

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил

# %% [markdown]
# #### Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам:

# %%
act_df.boxplot(column='total_sales', by='platform', figsize=(15, 5))
plt.title('Глобальные продажи игр в разбивке по платформам')
plt.xlabel('Платформа')
plt.ylabel('Глобальные продажи');

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить код с созданием выборки
#
#         ---------------------------------------------------------------------------
#         NameError                                 Traceback (most recent call last)
#         /tmp/ipykernel_97/155911135.py in <module>
#         ----> 1 act_df.boxplot(column='total_sales', by='platform', figsize=(15, 5))
#               2 plt.title('Глобальные продажи игр в разбивке по платформам')
#               3 plt.xlabel('Платформа')
#               4 plt.ylabel('Глобальные продажи');
#
#         NameError: name 'act_df' is not defined

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил

# %%
act_df.boxplot(column='total_sales', by='platform', figsize=(15, 10))
plt.title('Глобальные продажи игр в разбивке по платформам')
plt.xlabel('Платформа')
plt.ylabel('Глобальные продажи')
plt.ylim((0, 2));

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Не стоит ограничивать перечень платформ из актуального периода для оценки прибыльности платформ__
#
# диаграмму размаха перерисовать на актуальной выборке с полным перечнем платформ
#
# Оба вида важны, т.к. выбросы — это наши звезды, которые приносят максимум выручки

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Расширил

# %% [markdown]
# На графике по глобальным продажам игр в разбивке по платформам видим, что платформы 3DS, WiiU, PS4 и XOne имеют несколько крупных выбросов, особенно PS4 у которой были успешные игры с количеством продаж более 14 млн за копию, никто другой таким успехом похвастаться не может.
# Если обратить внимание на второй квартиль (медиану), то можно сказать, что большое количество рентабельных игр было выпущено на платформах 3DS, WiiU, PS4, XOne и X360, на них бы в 2017 года я и ориентировался бы

# %% [markdown]
# #### Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами

# %%
ps3_df = games_df.query("platform == 'PS3' and 0 < user_score <= 10 and 0 < critic_score <= 100 and total_sales > 0")

# %%
ps3_df.plot(x='critic_score', y='total_sales', kind='scatter') 
plt.title('Диаграмма рассеяния отношения продаж к оценкам критиков')
plt.xlabel('Оценка критиков')
plt.ylabel('Глобальные продажи');

# %%
ps3_df.plot(x='user_score', y='total_sales', kind='scatter') 
plt.title('Диаграмма рассеяния отношения продаж к оценкам пользователей')
plt.xlabel('Оценка пользователей')
plt.ylabel('Глобальные продажи');

# %%
ps3_df[['user_score', 'critic_score', 'total_sales']].corr()['total_sales']
# Out:
# user_score      0.143381
# critic_score    0.429181
# total_sales     1.000000
# Name: total_sales, dtype: float64

# %% [markdown]
# Согласно построенным диаграммам и таблице корреляции видно, что связь оценок пользователей с продажами отсутствует, коэффициент корреляции - 0.14. Однако слабая связь оценок критиков с продажами прослеживается, коэффицент корреляции 0.43.

# %% [markdown]
# #### Проанализируем ситуацию на других платформах:

# %%
for platform in games_df['platform'].unique():
    platform_df = games_df.query(f"platform == '{platform}'")
    if len(platform_df) > 100:
        print(platform)
        print(platform_df[['user_score', 'critic_score', 'total_sales']].corr()['total_sales'][:2])
        print("\r")
# Out:
# Wii
# user_score      0.112831
# critic_score    0.177907
# Name: total_sales, dtype: float64
#
# DS
# user_score      0.130876
# critic_score    0.237546
# Name: total_sales, dtype: float64
#
# X360
# user_score      0.114187
# critic_score    0.392866
# Name: total_sales, dtype: float64
#
# PS3
# user_score      0.127926
# critic_score    0.433712
# Name: total_sales, dtype: float64
#
# PS2
# user_score      0.175055
# critic_score    0.392536
# Name: total_sales, dtype: float64
#
# SNES
# user_score     NaN
# critic_score   NaN
# Name: total_sales, dtype: float64
#
# GBA
# user_score      0.106149
# critic_score    0.242107
# Name: total_sales, dtype: float64
#
# PS4
# user_score     -0.031957
# critic_score    0.406568
# Name: total_sales, dtype: float64
#
# 3DS
# user_score      0.222078
# critic_score    0.348740
# Name: total_sales, dtype: float64
#
# N64
# user_score     NaN
# critic_score   NaN
# Name: total_sales, dtype: float64
#
# PS
# user_score      0.300078
# ...

# %% [markdown]
# Единственная платформа со слабым коэффициентом корреляции продаж с оценками пользователей это WiiU. Посмотрим диаграммы рассеяния:

# %%
ps_df = games_df.query("platform == 'PS'")

# %%
ps_df.plot(x='critic_score', y='total_sales', kind='scatter') 
plt.title('Диаграмма рассеяния отношения продаж к оценкам критиков')
plt.xlabel('Оценка критиков')
plt.ylabel('Глобальные продажи');

# %%
ps_df.plot(x='user_score', y='total_sales', kind='scatter') 
plt.title('Диаграмма рассеяния отношения продаж к оценкам пользователей')
plt.xlabel('Оценка пользователей')
plt.ylabel('Глобальные продажи');

# %% [markdown]
# Везде картина приблизительно одинаковая, за исключением корреляции продаж с оценкам пользователей платформы PS. Это единственная платформа которая имеет слабую связь. Но ориентроваться на это я бы не стал. Слишком мало данных для анализа

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит избавиться от любых видов заглушек при расчете коэф. корреляции и строительстве графиков (нулевых, отрицательных, положительных)

# %% [markdown]
# <div class="alert">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не очень понял что ты имеешь ввиду. Исключил значения вне возможного диапазона в полях user_score, critic_score, total_sales

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я про наш способ заполнения пропусков медианой, он может полностью исказить данные расчетов

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить парочку диаграмм рассеяния, коэф. корреляции отображает лишь возможное наличие линейной связи

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил диаграммы рассеяния для платформы PS

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# <div class="alert alert-dange r">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При подобной величине коэффициента не важно какой у него знак, плюс или минус
#
#         В этих случаях коэффициент отрицательный.
#
#
# [Что считается «слабой» корреляцией?](https://www.codecamp.ru/blog/what-is-a-weak-correlation/?ysclid=lj70v6oyy6691340124)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил заключение

# %% [markdown]
# #### Посмотрим на общее распределение игр по жанрам

# %%
act_df.pivot_table(
    index='genre',
    values='total_sales',
    aggfunc='sum'
).sort_values(by='total_sales').plot(
    kind='barh', 
    grid=True, 
    figsize=(15, 5),
    legend=False
)
plt.title('Распределение суммарных продаж по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Суммарные продажи');

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит развернуть график в горизонтальные бары, если надписи оси Х не умещаются в горизонтальном виде

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Развернул

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %% [markdown]
# Видим, что тройка лидеров по продажам приходится на жанры: экшн, шутер и спорт. Стратегии - самый непопулярный жанр

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %%
act_df.boxplot(column='total_sales', by='genre', figsize=(15, 5))
plt.title('Глобальные продажи игр в разбивке по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Глобальные продажи');

# %%
act_df.boxplot(column='total_sales', by='genre', figsize=(15, 10), showfliers=False)
plt.title('Глобальные продажи игр в разбивке по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Глобальные продажи')
plt.ylim((0, 2));

# %% [markdown]
# Проанализировав прибыльность жанров на диаграмме размаха, можно сказать, что жанры Шутеры и Спорт обладают самыми высокими значениями медианы и имеет более длинный ряд успешно продающихся игр.
#
# Самая продающаяся игра попала в жанр Шутер (более 14 млн. копий).
#
# Паззлы и приключения являются самыми неудачными жанрами

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Ящики, усы и скрипки](https://habr.com/ru/articles/533726/)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)
#
# https://stackoverflow.com/questions/22028064/matplotlib-boxplot-without-outliers

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Убрал выбросы со второго графика

# %% [markdown]
# ## Шаг 4. Составим портрет пользователя каждого региона

# %%
regions = {'Северная Америка':'na_sales', 'Европа':'eu_sales', 'Япония':'jp_sales'}

# %%
def show_top(df, column):
    for region in regions:
        top = df[[regions[region], column]].groupby(by=column).sum().sort_values(by=regions[region], ascending=False)[:top_qty]
        print(top)
        top.plot(y=regions[region], kind='pie', figsize=(5, 5), ylabel=f"Топ-{top_qty}. Регион {region}")

# %% [markdown]
# #### Самые популярные платформы (топ-5):

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Круговая диаграмма из ТОП-5 искажает доли рынка, которые занимают первые топ-5 платформ, т.к. их сумма продаж делится на 100%, но у нас имеются другие платформы, которые также занимают определенную долю рынка

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец, значительное влияние на портрет оказывает период с 1980 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + выбрать актуальный период;
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделал

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример графиков
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %%
def get_top_df(df, region, column, qty):
    df1 = df[[region, column]].groupby(by=column).sum().sort_values(by=region, ascending=False)
    df1[column] = df1.index
    df2 = df1[:qty].copy()
    if len(df1) > qty:
        new_row = pd.DataFrame(data = {
            column : ['others'],
            region : [df1[region][qty:].sum()]
        })
        df2 = pd.concat([df2, new_row])
        df2.index = df2[column]
    return df2.drop(column, axis=1)

# %%
def show_top(column, main_title, qty):
    fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(18, 6))
    (
        get_top_df(act_df, 'na_sales', column, qty)
        .plot.pie(ax=axes[0], y='na_sales', autopct='%1.f%%', legend=False,
            wedgeprops = {"edgecolor" : "white", 
                          'linewidth': 2, 
                          'antialiased': True})
    )
    (
        get_top_df(act_df, 'eu_sales', column, qty)
        .plot.pie(ax=axes[1], y='eu_sales', autopct='%1.f%%', legend=False,
            wedgeprops = {"edgecolor" : "white", 
                          'linewidth': 2, 
                          'antialiased': True})
    )
    (
        get_top_df(act_df, 'jp_sales', column, qty)
        .plot.pie(ax=axes[2], y='jp_sales', autopct='%1.f%%', legend=False,
            wedgeprops = {"edgecolor" : "white", 
                          'linewidth': 2, 
                          'antialiased': True})
    )
    axes[0].title.set_text('Регион Северная Америка')
    axes[1].title.set_text('Регион Европа')
    axes[2].title.set_text('Регион Япония')
    axes[0].set_ylabel('')
    fig.suptitle(main_title, fontsize=30)

# %%
show_top('platform', 'Обзор рынка платформ (Портрет покупателя)', 5)

# %% [markdown]
# Топ платформ по регионам:
# - Северная Америка: PS4, XOne, 3DS, PS3, X360
# - Европа: PS4, XOne, PC, 3DS, PS3
# - Япония: 3DS, PS4, PSV, PS3, WiiU
#
# Можно заметить, что в Северной Америке и в Европе лидирует PS4, а в Японии 3DS. Неожиданно в Японии 3-е место занимает платформа PSV

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, молодец

# %% [markdown]
# #### Посмотрим самые популярные жанры:

# %%
show_top('genre', 'Обзор рынка жанров (Портрет покупателя)', 5)

# %% [markdown]
# Топ платформ по регионам:
# - Северная Америка: Шутер, Экшн, Спорт, Ролевые, Разное
# - Европа: Шутер, Экшн, Спорт, Ролевые, Гонки
# - Япония: Экшн, Ролевые, Шутер, Разное, Файтинг
#
# Видим, что в верхних строчка рейтинга всех регионов ожидаемо находятся жанры: экшн и шутеры. В Северной Америке и Европе также топ дополняют спорт, а в Японии ролевые игры. Думаю Это связано с менталитетом и культурой отдельных регионов.

# %% [markdown]
# #### Посмотрим влияние рейтинга на продажи в отдельных регионах

# %%
show_top('rating', 'Обзор рейтинга (Портрет покупателя)', 4)

# %% [markdown]
# Рейтинг в регионах Северная Америка и Европа большую часть занимает категория M (для взрослых), а далее идут рейтинги E(для всех) и T(для подростков). В Японии же самую большую долю занимает категоря для подростков, далее для всех и для взрослых

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах
#
# Стоит поработать со столбцом рейтингов, заменить пропуски, посмотреть на частотность использования всех категорий рейтинга

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделал

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить после исправления

# %% [markdown]
# ## Шаг 5. Проверим гипотезы

# %% [markdown]
# #### Проверим, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые.

# %% [markdown]
# Для этого сформируем гипотезы:
# - Нулевая гипотеза: средние пользовательские рейтинги платформ Xbox One и PC равны.
# - Альтернативная гипотеза: средние пользовательские рейтинги платформ Xbox One и PC отличаются

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно, для акцентирования можно использовать в нулевой гипотезе слово равны

# %%
len(games_df[games_df['platform'] == 'XOne']['user_score'])
# Out:
# 247

# %%
years = games_df[games_df['platform'] == 'XOne']['year_of_release'].unique()
years.sort()
years
# Out:
# array([2013, 2014, 2015, 2016])

# %%
xone_df = games_df.query("platform == 'XOne' and 0 <= user_score <= 10 and year_of_release in @years")
xone_df
# Out:
#                                  name platform  year_of_release         genre  \
# 165                Grand Theft Auto V     XOne             2014        Action
# 179    Call of Duty: Advanced Warfare     XOne             2014       Shooter
# 242                 Halo 5: Guardians     XOne             2015       Shooter
# 270                         Fallout 4     XOne             2015  Role-Playing
# 373           Assassin's Creed: Unity     XOne             2014        Action
# ...                               ...      ...              ...           ...
# 16544     Assassin's Creed Chronicles     XOne             2016        Action
# 16597     Saints Row: Gat out of Hell     XOne             2015        Action
# 16630        Sébastien Loeb Rally Evo     XOne             2016        Racing
# 16643               Rugby Challenge 3     XOne             2016        Sports
# 16660                Prison Architect     XOne             2016        Action
#
# ...

# %%
pc_df = games_df.query("platform == 'PC' and 0 <= user_score <= 10 and total_sales > 0 and year_of_release in @years")
pc_df
# Out:
#                                     name platform  year_of_release  \
# 458                           The Sims 4       PC             2014
# 1095    StarCraft II: Heart of the Swarm       PC             2013
# 1351                      SimCity (2013)       PC             2013
# 1437                       Battlefield 4       PC             2013
# 1530                           Fallout 4       PC             2015
# ...                                  ...      ...              ...
# 16456                  Fallout Anthology       PC             2015
# 16463                   TrackMania Turbo       PC             2016
# 16509                             Ride 2       PC             2016
# 16518               Rugby World Cup 2015       PC             2015
# 16692  Metal Gear Solid V: Ground Zeroes       PC             2014
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 458      Simulation      1.00      1.82       0.0         0.23          70.0
# ...

# %%
alpha = 0.05 # уровень статистической значимости. если p-value окажется меньше него, отвергнем гипотезу

results = st.ttest_ind(xone_df['user_score'], 
                       pc_df['user_score'], 
                       equal_var=False) # так как выборки разного размера

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p-значение: 0.14759594013430463
# Не отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит избавиться от любых видов заглушек (нулевых, отрицательных, положительных) при расчете стат. тестов

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Опять же не понимаю что ты имеешь ввиду. Исключил значения вне возможного диапазона в полях user_score

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />То, чем мы заполнили пропуски, может исказить результаты стат теста

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Полученное значение p-value говорит о том, что хотя средние пользовательские рейтинги платформ Xbox One и PC разные, с вероятностью в почти 15% такое или большее различие можно получить случайно. Исходя из этого, можно сделать вывод что, средние пользовательские рейтинги платформ Xbox One и PC равны

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит выравнивать периоды использования платформ, одна из приставок вышла на рынок совсем недавно ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Выровнил

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 4.3968409560037004e-05

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Это вероятность получить предполагаемого в нулевой гипотезе значения при условии, что предполагаемая нулевая гипотеза верна

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется делить на всем проекте
#
# <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# #### Проверим, что cредние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# Для этого сформируем гипотезы:
# - Нулевая гипотеза: cредние пользовательские рейтинги жанров Action и Sports одинаковые.
# - Альтернативная гипотеза: cредние пользовательские рейтинги жанров Action и Sports разные

# %%
sports_df = games_df.query("genre == 'Sports' and 0 < user_score <= 10")
action_df = games_df.query("genre == 'Action' and 0 < user_score <= 10")

# %%
alpha = 0.05 # уровень статистической значимости. если p-value окажется меньше него, отвергнем гипотезу

results = st.ttest_ind(action_df['user_score'], 
                       sports_df['user_score'], 
                       equal_var=False) # так как выборки разного размера

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p-значение: 0.07751671595536253
# Не отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит избавиться от любых видов заглушек (нулевых, отрицательных, положительных) при расчете стат. тестов

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Получили значение p-value 7.7%, исходя из этого можно сделать вывод что, cредние пользовательские рейтинги жанров Action и Sports одинаковые. Однако, если бы мы выбрали уровень статистической значимости в 10%, то нулевую гипотезу пришлось бы отвергнуть.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит отметить в выводе, что два стат теста выполнялись на разных временных промежутках, иногда этот факт играет особую роль для менеджеров

# %% [markdown]
# ## Вывод
# 1. Были выгружены датасет о продажах игр, оценки пользователей и экспертов, жанры и платформы более 16000 записей
#
# 2. В ходе анализа датасета был выявлен ряд проблем и их решения:
# - Приведены к нижнему регистру символ в названиях столбцов
# - Значение в поле user_score "tbd" было заменено на NaN чтобы можно было преобразовать столбец к вещественному типу
# - Тип данных year_of_release был приведен к целочисленному типу
# - Тип данных user_score был приведен к вещественному типу
# - Записи с пропусками в полях year_of_release и genre из-за малого их количества и малой значимости были удалены
# - Малочисленные категории в рейтинге были объединены, а пропуски заполнены самой популярной категорией в каждом жанре
# - Пропуски в полях user_score и critic_score заполнены медианой в соответствии с платформой и годом выпуска
# - Удалены дубликаты по ключевым столбцам 'name', 'platform', 'year_of_release'
#
#
# 3. После устранения указанных проблем, были изучены и отмечены следующие особенности в данных:
# - данные до 1994 года особого интереса не представляют. В этот период игры были еще не популярны и продаж было мало. Пик популярности пришел на 2008-2009 год, в этот период выпускалось более 1400 игр в год.
# - приблизительное время выхода платформы на пик популярности - 5 лет, а через следующие 5 лет платформа теряет актуальность
# - период, оказывающий серьезное влияние на прогноз на 2017 выбран 2 года
# - в актуальном периоде набирают популярность только две платформы, PS4 и XOne, на них можно ориентироваться в 2017 году. Платформы PS3 и X360 теряют свою актуальность и делать упор на них в 2017 году не стоит. Платформа 3DS находится в нейтральном состоянии и списывать её со счетов пока не стоит. Тем более, что в описании проекта указано, что данные за 2016 год могут быть неполными.
# - в Северной Америке и в Европе лидирует PS4, а в Японии 3DS. Неожиданно в Японии 3-е место занимает платформа PSV
# - в верхних строчка рейтинга всех регионов ожидаемо находятся жанры: экшн и шутеры. В Северной Америке и Европе также топ дополняют спорт, а в Японии ролевые игры. Думаю Это связано с менталитетом и культурой отдельных регионов.
# - Рейтинг в регионах Северная Америка и Европа большую часть занимает категория M (для взрослых), а далее идут рейтинги E(для всех) и T(для подростков). В Японии же самую большую долю занимает категоря для подростков, далее для всех и для взрослых
#
# 4. В ходе проверки гипотез можно сделать следующие заключения:
# - средние пользовательские рейтинги платформ Xbox One и PC равны
# - cредние пользовательские рейтинги жанров Action и Sports равны

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после определения актуального периода и исправления всех комментариев, можно обновить названия самых актуальных платформ, жанров и рейтингов, какую долю они занимают на исследуемых рынках

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + добавить название
#  + заполнение пропусков
#  + обработать пропуски и сократить категории в рейтингах ESRB — на твое усмотрение
#  + выполнить проверку на дублирование записей
#  + определить за какой характерный срок появляются новые и исчезают старые платформы — на твое усмотрение
#  + самое важное — определить актуальный период
#  + исправить диаграммы размаха для анализа продаж на актуальных платформах
#  + поправить исследование зависимости по платформам конкурентам (от оценок критиков и пользователей)
#  + оценить прибыльность жанров на диаграмме размаха
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез подправить выборки плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
#
# Плюс
#
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)

# %% [markdown]
# ## Бонус

# %%
data_games = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие

# функция не работает на версии библиотеки pandas = 2.0 (метод .append устарел)

def graph (df, year, region, name, axes):
    
    df = df.query('year_of_release >= @year')
    
    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()
    
    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
    
    sales.columns = ['platform', 'sales']
      
# Цветовая гамма не подбиралась специально под платформы, кому-что попадется, 😉      
      
    labels_c=sales.platform
    colours = {'Wii':'C60', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'lightsteelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'Fuchsia', '2600':'C15', 'PSP':'C48', 
               'XOne':'LimeGreen',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
    plt.tight_layout()

# %%
# check
# круги в ряд

x_year = 2007

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %%
# check
# круги в ряд

x_year = 2012

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оптимальный период для исследования 2014-2016 гг., т.к. данные за 2016 г. неполные

# %%
# check
# круги в ряд

x_year = 2014

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ

# %%
# check
# круги в ряд

x_year = 2015

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])
